# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
def requests_():
    address = str(input("Please enter the url: "))
    page= requests.get(address)
    
    # create a BeautifulSoup Object
    soup = BeautifulSoup(page.text, 'html.parser')

# %%
def initial_check():
    link_good()
    blocked()
    content_type()

# %%
def content_type():
    print("Content Type:",end='\n')
    print(r.headers.get("content-type","unknown"),end='\n')
    print('\n')

# %%
def blocked():
    if "blocked" in r.text:
        print("blocked status:", end='\n')
        print(" we've been blocked", end='\n')
        print('\n')
    else:
        print("blocked status:", end='\n')
        print(" Not blocked", end='\n')
        print('\n')

# %%
def link_good():
    
    if r.status_code == 200:
        print("link status:", end='\n')
        print(" The link is goood", end='\n')
        print('\n')
    elif r.status_code == 400 or r.status_code == 500:
        print("link status:", end='\n')
        print(" The link is bad", end='\n')
        print('\n')

# %%
initial_check()
# Out:
# link status:
#  The link is goood
#
#
# blocked status:
#  Not blocked
#
#
# Content Type:
# text/html; charset=UTF-8

# %%
requests_()
# Out:
# Please enter the url: http://www.nbaminer.com/player-basic-stats/

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.NavigableString,
#  bs4.element.Doctype,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.NavigableString,
#  bs4.element.Comment]

# %% [markdown]
# ## Notes:
#
# All items are BeuatifulSoup objects. The first is a NavigableString, which represents text found in the HTML. The second is a Doctype object which contains information about the type of the document. The third is a Tag object, contains nested tags. Lastly is comment object which I assume just contains comments about the document.

# %%
tag = list(soup.children)[3]

# %%
tag
# Out:
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1,user-scalable=no" name="viewport"/>
# <title>NBA Miner | NBA Player Advanced Stats- Player Basic Stats</title>
# <meta content="Daily updated NBA Advanced Player Stats- Basic stats (since 1996-1997 season) " name="description"/>
# <meta content="NBA Stats, NBA Advanced Stats, NBA Stats per game, Pace, nba wins, nba scores, basketball, basketball analytics, basketball advanced stats, nba player stats, nba advanced player stats, basic stats" name="keywords"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="http://www.nbaminer.com/xmlrpc.php" rel="pingback"/>
# <link href="http://www.nbaminer.com/wp-content/uploads/2014/06/logo2.png" rel="shortcut icon" type="image/x-icon"/>
# <!--[if gte IE 9]>
# 		<style type="text/css">
# 			.gradient {
# 				 filter: none;
# 			}
# 		</style>
# 	<![endif]-->
# ...

# %% [markdown]
# ## Notes:
#
# once we created a list of every type of object in the original document we can now access different aspects of it. To really navigate the document we want to choose the "tag" object.
